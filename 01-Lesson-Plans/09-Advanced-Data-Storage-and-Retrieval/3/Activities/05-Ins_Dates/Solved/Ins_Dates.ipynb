# %%
from sqlalchemy import create_engine, inspect, func
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

import pymysql
pymysql.install_as_MySQLdb()

engine = create_engine('mysql://root:sillypassword@localhost:3306/sakila')
session = Session(bind=engine)

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine, reflect=True)

Actor = Base.classes.actor
Address = Base.classes.address
City = Base.classes.city
Country = Base.classes.country
Category = Base.classes.category
Customer = Base.classes.customer
Store = Base.classes.store
Staff = Base.classes.staff
Film = Base.classes.film
Language = Base.classes.language
FilmActor = Base.classes.film_actor
FilmCategory = Base.classes.film_category
FilmText = Base.classes.film_text
Inventory = Base.classes.inventory
Payment = Base.classes.payment
Rental = Base.classes.rental
# Out:
# /Users/tyler/virtualenvs36/test/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/reflection.py:181: SAWarning: Did not recognize type 'geometry' of column 'location'
#   (type_, name))

# %%
session.query(
    func.min(Payment.payment_date),
    func.max(Payment.payment_date)
).first()
# Out:
# (datetime.datetime(2005, 5, 24, 22, 53, 30),
#  datetime.datetime(2006, 2, 14, 15, 16, 3))

# %%
min_date, max_date = session.query(
    func.min(Payment.payment_date),
    func.max(Payment.payment_date)
).first()
print(min_date)
print(max_date)
# Out:
# 2005-05-24 22:53:30
# 2006-02-14 15:16:03

# %%
session.query(
    Payment.payment_date
).filter(
    Payment.payment_date > '2006'
).limit(20).all()
# Out:
# /Users/tyler/virtualenvs36/test/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2006' for column 'payment_date' at row 1")
#   result = self._query(query)
# [(datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
# ...

# %%
import datetime as dt
print(dt.date.today())
print(dt.date(2017, 1 ,31))
# Out:
# 2018-08-26
# 2017-01-31

# %%
print(dt.datetime.today())
print(dt.datetime(2017, 1 ,31))
# Out:
# 2018-08-26 18:07:59.123790
# 2017-01-31 00:00:00

# %%
# date 1 week ago from today
week_ago = dt.datetime.today() - dt.timedelta(days=7)
print(week_ago)
# Out:
# 2018-08-19 18:07:59.131893

# %%
session.query(
    func.min(Payment.payment_date),
    func.max(Payment.payment_date)
).filter(
    Payment.payment_date < dt.date(2006, 1, 1)
).first()
# Out:
# (datetime.datetime(2005, 5, 24, 22, 53, 30),
#  datetime.datetime(2005, 8, 23, 22, 50, 12))

# %%
from sqlalchemy import extract
session.query(
    Payment.payment_date
).filter(
    extract('year', Payment.payment_date) == 2006
).all()
# Out:
# [(datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  (datetime.datetime(2006, 2, 14, 15, 16, 3)),
# ...

# %%
session.query(
    Payment.payment_date
).filter(
    extract('month', Payment.payment_date) == 6,
    extract('day', Payment.payment_date) == 15,
).all()
# Out:
# [(datetime.datetime(2005, 6, 15, 0, 54, 12)),
#  (datetime.datetime(2005, 6, 15, 18, 2, 53)),
#  (datetime.datetime(2005, 6, 15, 21, 8, 46)),
#  (datetime.datetime(2005, 6, 15, 9, 31, 28)),
#  (datetime.datetime(2005, 6, 15, 22, 3, 14)),
#  (datetime.datetime(2005, 6, 15, 9, 59, 16)),
#  (datetime.datetime(2005, 6, 15, 20, 53, 7)),
#  (datetime.datetime(2005, 6, 15, 13, 32, 15)),
#  (datetime.datetime(2005, 6, 15, 19, 30, 18)),
#  (datetime.datetime(2005, 6, 15, 12, 17, 34)),
#  (datetime.datetime(2005, 6, 15, 14, 9, 55)),
#  (datetime.datetime(2005, 6, 15, 18, 53, 14)),
#  (datetime.datetime(2005, 6, 15, 10, 11, 42)),
#  (datetime.datetime(2005, 6, 15, 21, 17, 17)),
#  (datetime.datetime(2005, 6, 15, 4, 58, 7)),
#  (datetime.datetime(2005, 6, 15, 9, 46, 33)),
#  (datetime.datetime(2005, 6, 15, 5, 55, 40)),
#  (datetime.datetime(2005, 6, 15, 21, 56, 39)),
#  (datetime.datetime(2005, 6, 15, 3, 18, 40)),
#  (datetime.datetime(2005, 6, 15, 4, 44, 10)),
# ...
