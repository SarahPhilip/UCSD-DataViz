# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo
import datetime

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('li', class_='mixed-feed__item--article')

# Loop through results to retrieve article title, header, and timestamp of article
for result in results:
    title = result.find('h4', class_='mixed-feed__header').text

    lede = result.find('h5', class_='mixed-feed__subheader').text

    # The time and date of article publication
    dt_str = result.find('time')['datetime']
    dt = datetime.datetime.strptime(dt_str, '%Y-%m-%dT%H:%M:%S%z')
    article_date = dt.strftime('%Y-%m-%d')
    time = dt.strftime('%I:%M%p')

    print('-----------------')
    print(title)
    print(lede)
    print(article_date)
    print(time)

    # Dictionary to be inserted into MongoDB
    post = {
        'title': title,
        'lede': lede,
        'date': article_date,
        'time_published': time
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Karlsson attends Senators golf tournament
# Defenseman, subject of trade rumors, does not speak to media
# 2018-09-12
# 05:12PM
# -----------------
# Tortorella gets two-year contract extension with Blue Jackets
# Winningest U.S.-born coach in NHL history signed through 2020-21
# 2018-09-12
# 03:53PM
# -----------------
# Fantasy top 250 rankings for 2018-19
# McDavid, Ovechkin lead consensus list; impact of Pacioretty trade on Golden Knights, Canadiens
# 2018-09-11
# 06:15PM
# -----------------
# Wennberg eyes bounce-back season for Blue Jackets
# Columbus center embracing chance 'to be better than I showed last year'
# 2018-09-13
# 12:00AM
# -----------------
# Gibson's alternate mask honors Pittsburgh, Ducks championship team
# Anaheim goalie goalie pays homage to hometown, 2006-07 team with 25th anniversary helmet
# 2018-09-12
# 07:55PM
# -----------------
# Johansen, Predators out to prove they can win Cup
# Center says team can learn from falling short after winning Presidents' Trophy last season
# 2018-09-12
# 11:08AM
# -----------------
# Boeser not focused on contract negotiations with Canucks
# Forward led Vancouver with 29 goals last season, will 'worry about it after the season'
# 2018-09-12
# 08:03PM
# -----------------
# How eight Eastern Conference teams can get back into playoffs
# Panthers, Rangers, Sabres among those who didn't qualify last season
# 2018-09-12
# 12:00AM
# -----------------
# Yzerman leaving as Lightning GM leads to more questions than answers
# Says 'I don't know' about future beyond this season
# 2018-09-11
# 07:42PM
# -----------------
# Fantasy: First line rankings for 2018-19
# O'Reilly will get chance to center Tarasenko; Sabres rise into top 15 with Skinner
# 2018-09-10
# 04:00PM
# -----------------
# Bruins, Flames arrive for China Games
# Set for first practices in Shenzhen following 15-hour flights
# 2018-09-12
# 08:25AM
# -----------------
# Watson of Predators suspended 27 games by NHL
# Forward disciplined for unacceptable off-ice conduct
# 2018-09-12
# 07:45PM
# -----------------
# Pacioretty 'going to fit well,' Golden Knights believe
# Forward signed four-year contract after trade with Canadiens
# 2018-09-11
# 05:36PM
# -----------------
# Schmaltz agrees to two-year deal with Blues
#
# 2018-09-12
# 11:35AM
# -----------------
# Chychrun to miss start of training camp for Coyotes: report
# Defenseman rehabbing knee injury, no timetable for return
# 2018-09-12
# 04:00PM
# -----------------
# BriseBois expects 'business as usual' taking over as Lightning GM
# 41-year-old spent eight years as assistant to Yzerman
# 2018-09-11
# 08:19PM
# -----------------
# Pastrnak will feel at home during China Games with Bruins
# Forward making third visit to country in three years
# 2018-09-11
# 12:00AM
# -----------------
# NHL Network to show 27 live preseason games
# Schedule includes China Games, Global Series Challenge
# 2018-09-12
# 10:00AM
# -----------------
# Predators, NHLPA statements on Austin Watson
# Forward suspended 27 games by NHL for unacceptable off-ice conduct
# 2018-09-12
# 09:17PM
# -----------------
# Suzuki eyes roster spot with Canadiens
# Center, acquired in trade with Golden Knights, could play with Montreal this season
# 2018-09-11
# 03:51PM
# -----------------
# Yzerman tenure with Lightning highlighted by trip to Cup Final in 2015
# Retaining Stamkos also among accomplishments for Hockey Hall of Famer who resigned as GM
# 2018-09-11
# 05:34PM
# -----------------
# RELEASE: Blackhawks to honor Mikita on opening night
# The Blackhawks announced the team will honor the life and career of the late Stan Mikita in a pregame ceremony before the team's home opener on Sunday, October 7
# 2018-09-12
# 02:59PM
# -----------------
# Bishop feels healthy ahead of Stars training camp
# Goaltender injured left knee last season, doesn't see there 'being any setbacks'
# 2018-09-11
# 07:04PM
# -----------------
# Gilbert had ultimate photo bomb on Fischler
# Rangers Hall of Famer made life miserable for reporter-turned-goalie
# 2018-09-12
# 12:00AM
# -----------------
# Kuznetsov says Stanley Cup win still surreal, dreams of Capitals repeat
# Forward describes emotion of bringing trophy to native Russia, believes Washington can do it again
# 2018-09-11
# 11:50AM
# -----------------
# Couturier hopes to play preseason games with Flyers
# Center skating, recovering from lower-body injury sustained Aug. 10
# 2018-09-11
# 04:00PM
# -----------------
# 2018-19 NHL Trade Tracker
# Official deals since June 8
# 2018-09-11
# 10:41AM

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5b99e671b84a80dc3fadc8a6'), 'title': 'Karlsson attends Senators golf tournament', 'lede': 'Defenseman, subject of trade rumors, does not speak to media', 'date': '2018-09-12', 'time_published': '05:12PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8a7'), 'title': 'Tortorella gets two-year contract extension with Blue Jackets', 'lede': 'Winningest U.S.-born coach in NHL history signed through 2020-21', 'date': '2018-09-12', 'time_published': '03:53PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8a8'), 'title': 'Fantasy top 250 rankings for 2018-19', 'lede': 'McDavid, Ovechkin lead consensus list; impact of Pacioretty trade on Golden Knights, Canadiens', 'date': '2018-09-11', 'time_published': '06:15PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8a9'), 'title': 'Wennberg eyes bounce-back season for Blue Jackets', 'lede': "Columbus center embracing chance 'to be better than I showed last year'", 'date': '2018-09-13', 'time_published': '12:00AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8aa'), 'title': "Gibson's alternate mask honors Pittsburgh, Ducks championship team", 'lede': 'Anaheim goalie goalie pays homage to hometown, 2006-07 team with 25th anniversary helmet', 'date': '2018-09-12', 'time_published': '07:55PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8ab'), 'title': 'Johansen, Predators out to prove they can win Cup', 'lede': "Center says team can learn from falling short after winning Presidents' Trophy last season", 'date': '2018-09-12', 'time_published': '11:08AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8ac'), 'title': 'Boeser not focused on contract negotiations with Canucks', 'lede': "Forward led Vancouver with 29 goals last season, will 'worry about it after the season'", 'date': '2018-09-12', 'time_published': '08:03PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8ad'), 'title': 'How eight Eastern Conference teams can get back into playoffs', 'lede': "Panthers, Rangers, Sabres among those who didn't qualify last season", 'date': '2018-09-12', 'time_published': '12:00AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8ae'), 'title': 'Yzerman leaving as Lightning GM leads to more questions than answers', 'lede': "Says 'I don't know' about future beyond this season", 'date': '2018-09-11', 'time_published': '07:42PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8af'), 'title': 'Fantasy: First line rankings for 2018-19', 'lede': "O'Reilly will get chance to center Tarasenko; Sabres rise into top 15 with Skinner", 'date': '2018-09-10', 'time_published': '04:00PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b0'), 'title': 'Bruins, Flames arrive for China Games', 'lede': 'Set for first practices in Shenzhen following 15-hour flights', 'date': '2018-09-12', 'time_published': '08:25AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b1'), 'title': 'Watson of Predators suspended 27 games by NHL', 'lede': 'Forward disciplined for unacceptable off-ice conduct', 'date': '2018-09-12', 'time_published': '07:45PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b2'), 'title': "Pacioretty 'going to fit well,' Golden Knights believe", 'lede': 'Forward signed four-year contract after trade with Canadiens', 'date': '2018-09-11', 'time_published': '05:36PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b3'), 'title': 'Schmaltz agrees to two-year deal with Blues', 'lede': '', 'date': '2018-09-12', 'time_published': '11:35AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b4'), 'title': 'Chychrun to miss start of training camp for Coyotes: report', 'lede': 'Defenseman rehabbing knee injury, no timetable for return', 'date': '2018-09-12', 'time_published': '04:00PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b5'), 'title': "BriseBois expects 'business as usual' taking over as Lightning GM", 'lede': '41-year-old spent eight years as assistant to Yzerman', 'date': '2018-09-11', 'time_published': '08:19PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b6'), 'title': 'Pastrnak will feel at home during China Games with Bruins', 'lede': 'Forward making third visit to country in three years', 'date': '2018-09-11', 'time_published': '12:00AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b7'), 'title': 'NHL Network to show 27 live preseason games', 'lede': 'Schedule includes China Games, Global Series Challenge', 'date': '2018-09-12', 'time_published': '10:00AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b8'), 'title': 'Predators, NHLPA statements on Austin Watson', 'lede': 'Forward suspended 27 games by NHL for unacceptable off-ice conduct', 'date': '2018-09-12', 'time_published': '09:17PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8b9'), 'title': 'Suzuki eyes roster spot with Canadiens', 'lede': 'Center, acquired in trade with Golden Knights, could play with Montreal this season', 'date': '2018-09-11', 'time_published': '03:51PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8ba'), 'title': 'Yzerman tenure with Lightning highlighted by trip to Cup Final in 2015', 'lede': 'Retaining Stamkos also among accomplishments for Hockey Hall of Famer who resigned as GM', 'date': '2018-09-11', 'time_published': '05:34PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8bb'), 'title': 'RELEASE: Blackhawks to honor Mikita on opening night', 'lede': "The Blackhawks announced the team will honor the life and career of the late Stan Mikita in a pregame ceremony before the team's home opener on Sunday, October 7", 'date': '2018-09-12', 'time_published': '02:59PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8bc'), 'title': 'Bishop feels healthy ahead of Stars training camp', 'lede': "Goaltender injured left knee last season, doesn't see there 'being any setbacks'", 'date': '2018-09-11', 'time_published': '07:04PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8bd'), 'title': 'Gilbert had ultimate photo bomb on Fischler', 'lede': 'Rangers Hall of Famer made life miserable for reporter-turned-goalie', 'date': '2018-09-12', 'time_published': '12:00AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8be'), 'title': 'Kuznetsov says Stanley Cup win still surreal, dreams of Capitals repeat', 'lede': 'Forward describes emotion of bringing trophy to native Russia, believes Washington can do it again', 'date': '2018-09-11', 'time_published': '11:50AM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8bf'), 'title': 'Couturier hopes to play preseason games with Flyers', 'lede': 'Center skating, recovering from lower-body injury sustained Aug. 10', 'date': '2018-09-11', 'time_published': '04:00PM'}
# {'_id': ObjectId('5b99e671b84a80dc3fadc8c0'), 'title': '2018-19 NHL Trade Tracker', 'lede': 'Official deals since June 8', 'date': '2018-09-11', 'time_published': '10:41AM'}
